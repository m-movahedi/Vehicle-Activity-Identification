# %%
# !pip install streamlit-extras
# Out:
# Collecting streamlit-extras
#   Using cached streamlit_extras-0.4.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting entrypoints>=0.4 (from streamlit-extras)
#   Using cached entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting htbuilder>=0.6.2 (from streamlit-extras)
#   Using cached htbuilder-0.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting markdownlit>=0.0.5 (from streamlit-extras)
#   Using cached markdownlit-0.0.7-py3-none-any.whl.metadata (14 kB)
# Collecting prometheus-client>=0.14.0 (from streamlit-extras)
#   Using cached prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: protobuf!=3.20.2 in ./.venv/lib/python3.12/site-packages (from streamlit-extras) (4.25.3)
# Collecting st-annotated-text>=3.0.0 (from streamlit-extras)
#   Using cached st_annotated_text-4.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting st-theme>=1.0.1 (from streamlit-extras)
#   Using cached st_theme-1.2.3-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: streamlit>=1.0.0 in ./.venv/lib/python3.12/site-packages (from streamlit-extras) (1.26.0)
# Collecting streamlit-camera-input-live>=0.2.0 (from streamlit-extras)
#   Using cached streamlit_camera_input_live-0.2.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting streamlit-card>=0.0.4 (from streamlit-extras)
#   Using cached streamlit_card-1.0.2-py3-none-any.whl.metadata (4.0 kB)
# Collecting streamlit-embedcode>=0.1.2 (from streamlit-extras)
#   Using cached streamlit_embedcode-0.1.2-py3-none-any.whl.metadata (414 bytes)
# Collecting streamlit-faker>=0.0.2 (from streamlit-extras)
#   Using cached streamlit_faker-0.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-image-coordinates<0.2.0,>=0.1.1 (from streamlit-extras)
#   Using cached streamlit_image_coordinates-0.1.9-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-keyup>=0.1.9 (from streamlit-extras)
#   Using cached streamlit_keyup-0.2.4-py3-none-any.whl.metadata (2.0 kB)
# Collecting streamlit-toggle-switch>=1.0.2 (from streamlit-extras)
#   Using cached streamlit_toggle_switch-1.0.2-py3-none-any.whl.metadata (395 bytes)
# Collecting streamlit-vertical-slider>=2.5.5 (from streamlit-extras)
#   Using cached streamlit_vertical_slider-2.5.5-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: validators>=0.20.0 in ./.venv/lib/python3.12/site-packages (from streamlit-extras) (0.28.3)
# Collecting more-itertools (from htbuilder>=0.6.2->streamlit-extras)
#   Using cached more_itertools-10.3.0-py3-none-any.whl.metadata (36 kB)
# Collecting markdown (from markdownlit>=0.0.5->streamlit-extras)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting lxml (from markdownlit>=0.0.5->streamlit-extras)
#   Downloading lxml-5.2.2-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.4 kB)
# Collecting favicon (from markdownlit>=0.0.5->streamlit-extras)
#   Using cached favicon-0.7.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Collecting pymdown-extensions (from markdownlit>=0.0.5->streamlit-extras)
#   Using cached pymdown_extensions-10.8.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting streamlit>=1.0.0 (from streamlit-extras)
#   Using cached streamlit-1.35.0-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: altair<6,>=4.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (8.1.7)
# Requirement already satisfied: numpy<2,>=1.19.3 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (1.26.4)
# Requirement already satisfied: packaging<25,>=16.8 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (23.2)
# Requirement already satisfied: pandas<3,>=1.3.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (9.5.0)
# Requirement already satisfied: pyarrow>=7.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (16.1.0)
# Requirement already satisfied: requests<3,>=2.27 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (8.4.1)
# Requirement already satisfied: toml<2,>=0.10.1 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in ./.venv/lib/python3.12/site-packages (from streamlit>=1.0.0->streamlit-extras) (6.4.1)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.12/site-packages (from streamlit-camera-input-live>=0.2.0->streamlit-extras) (3.1.4)
# Collecting faker (from streamlit-faker>=0.0.2->streamlit-extras)
#   Using cached Faker-25.8.0-py3-none-any.whl.metadata (15 kB)
# Collecting matplotlib (from streamlit-faker>=0.0.2->streamlit-extras)
#   Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: jsonschema>=3.0 in ./.venv/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.0.0->streamlit-extras) (4.22.0)
# Requirement already satisfied: toolz in ./.venv/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.0.0->streamlit-extras) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./.venv/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.0.0->streamlit-extras) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit>=1.0.0->streamlit-extras) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit>=1.0.0->streamlit-extras) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas<3,>=1.3.0->streamlit>=1.0.0->streamlit-extras) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.12/site-packages (from jinja2->streamlit-camera-input-live>=0.2.0->streamlit-extras) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.0.0->streamlit-extras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.0.0->streamlit-extras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.0.0->streamlit-extras) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.0.0->streamlit-extras) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit>=1.0.0->streamlit-extras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit>=1.0.0->streamlit-extras) (2.18.0)
# Collecting beautifulsoup4>=4.7.0 (from favicon->markdownlit>=0.0.5->streamlit-extras)
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras)
#   Downloading contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras)
#   Downloading fonttools-4.53.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (162 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 2.5 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras)
#   Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->streamlit-faker>=0.0.2->streamlit-extras)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting pyyaml (from pymdown-extensions->markdownlit>=0.0.5->streamlit-extras)
#   Downloading PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4>=4.7.0->favicon->markdownlit>=0.0.5->streamlit-extras)
#   Using cached soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./.venv/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.0.0->streamlit-extras) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.0.0->streamlit-extras) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.0.0->streamlit-extras) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.0.0->streamlit-extras) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in ./.venv/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.0.0->streamlit-extras) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.0.0->streamlit-extras) (0.1.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=1.0.0->streamlit-extras) (1.16.0)
# Using cached streamlit_extras-0.4.3-py3-none-any.whl (72 kB)
# Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Using cached htbuilder-0.6.2-py3-none-any.whl (12 kB)
# Using cached markdownlit-0.0.7-py3-none-any.whl (15 kB)
# Using cached prometheus_client-0.20.0-py3-none-any.whl (54 kB)
# Using cached st_annotated_text-4.0.1-py3-none-any.whl (9.0 kB)
# Using cached st_theme-1.2.3-py3-none-any.whl (75 kB)
# Using cached streamlit-1.35.0-py2.py3-none-any.whl (8.6 MB)
# Using cached streamlit_camera_input_live-0.2.0-py3-none-any.whl (6.6 kB)
# Using cached streamlit_card-1.0.2-py3-none-any.whl (680 kB)
# Using cached streamlit_embedcode-0.1.2-py3-none-any.whl (3.5 kB)
# Using cached streamlit_faker-0.0.3-py3-none-any.whl (14 kB)
# Using cached streamlit_image_coordinates-0.1.9-py3-none-any.whl (7.0 kB)
# Using cached streamlit_keyup-0.2.4-py3-none-any.whl (7.4 kB)
# Using cached streamlit_toggle_switch-1.0.2-py3-none-any.whl (635 kB)
# Using cached streamlit_vertical_slider-2.5.5-py3-none-any.whl (1.8 MB)
# Using cached Faker-25.8.0-py3-none-any.whl (1.8 MB)
# Using cached favicon-0.7.0-py2.py3-none-any.whl (5.9 kB)
# Downloading lxml-5.2.2-cp312-cp312-macosx_10_9_universal2.whl (8.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 43.5 MB/s eta 0:00:0000:0100:01
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Downloading matplotlib-3.9.0-cp312-cp312-macosx_11_0_arm64.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 57.7 MB/s eta 0:00:00a 0:00:01m
# Using cached more_itertools-10.3.0-py3-none-any.whl (59 kB)
# Using cached pymdown_extensions-10.8.1-py3-none-any.whl (250 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Downloading contourpy-1.2.1-cp312-cp312-macosx_11_0_arm64.whl (245 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 30.0 MB/s eta 0:00:00
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.53.0-cp312-cp312-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 85.6 MB/s eta 0:00:00
# Downloading kiwisolver-1.4.5-cp312-cp312-macosx_11_0_arm64.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 11.5 MB/s eta 0:00:00
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Downloading PyYAML-6.0.1-cp312-cp312-macosx_11_0_arm64.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 25.3 MB/s eta 0:00:00
# Using cached soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, pyyaml, pyparsing, prometheus-client, more-itertools, markdown, lxml, kiwisolver, fonttools, entrypoints, cycler, contourpy, pymdown-extensions, matplotlib, htbuilder, faker, beautifulsoup4, st-annotated-text, favicon, streamlit, streamlit-vertical-slider, streamlit-toggle-switch, streamlit-keyup, streamlit-image-coordinates, streamlit-embedcode, streamlit-card, streamlit-camera-input-live, st-theme, streamlit-faker, markdownlit, streamlit-extras
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.26.0
#     Uninstalling streamlit-1.26.0:
#       Successfully uninstalled streamlit-1.26.0
# Successfully installed beautifulsoup4-4.12.3 contourpy-1.2.1 cycler-0.12.1 entrypoints-0.4 faker-25.8.0 favicon-0.7.0 fonttools-4.53.0 htbuilder-0.6.2 kiwisolver-1.4.5 lxml-5.2.2 markdown-3.6 markdownlit-0.0.7 matplotlib-3.9.0 more-itertools-10.3.0 prometheus-client-0.20.0 pymdown-extensions-10.8.1 pyparsing-3.1.2 pyyaml-6.0.1 soupsieve-2.5 st-annotated-text-4.0.1 st-theme-1.2.3 streamlit-1.35.0 streamlit-camera-input-live-0.2.0 streamlit-card-1.0.2 streamlit-embedcode-0.1.2 streamlit-extras-0.4.3 streamlit-faker-0.0.3 streamlit-image-coordinates-0.1.9 streamlit-keyup-0.2.4 streamlit-toggle-switch-1.0.2 streamlit-vertical-slider-2.5.5

# %%
from datetime import datetime, timedelta
import pandas as pd
date = pd.to_datetime('2017-01-01').date()
time = datetime.combine(date, datetime.min.time()) + timedelta(hours=12, minutes=31, seconds=39)
sensor = "1"

# %%
IMU = pd.read_csv('Misc\dataLog00008.TXT', sep=',', header=0)
IMU= IMU[IMU.columns[:13]]
IMU['Time'] = pd.to_datetime(IMU['rtcDate']+ ' ' + IMU['rtcTime'])
IMU['Time'] = IMU['Time']- IMU.iloc[0]['Time']
IMU['Time'] = IMU['Time'].dt.total_seconds()
IMU['Time'] = IMU['Time'].apply(lambda x: time + pd.Timedelta(milliseconds=x))
IMU = IMU[['Time']+list(IMU.columns[2:-2])]
IMU.set_index('Time', inplace=True)
IMU.columns = [str(sensor)+'_'+str(col) for col in IMU.columns]

# %%
IMU['Time']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Time'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 IMU['Time']
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'Time'

# %%
df
# Out:
#                             <function <listcomp>.<lambda> at 0x00000139E2730360>  \
# Time
# 2017-01-01 12:31:39.000000                                             848.14
# 2017-01-01 12:31:39.000020                                             842.29
# 2017-01-01 12:31:39.000040                                             859.86
# 2017-01-01 12:31:39.000050                                             844.73
# 2017-01-01 12:31:39.000060                                             840.33
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            -698.73
# 2017-01-01 12:31:42.174360                                            -411.13
# 2017-01-01 12:31:42.174370                                              93.75
# 2017-01-01 12:31:42.174380                                            -624.02
# 2017-01-01 12:31:42.174390                                            -560.06
#
#                             <function <listcomp>.<lambda> at 0x00000139E279E700>  \
# Time
# 2017-01-01 12:31:39.000000                                            -465.82
# 2017-01-01 12:31:39.000020                                            -472.17
# 2017-01-01 12:31:39.000040                                            -486.82
# 2017-01-01 12:31:39.000050                                            -481.93
# 2017-01-01 12:31:39.000060                                            -473.14
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            -401.86
# 2017-01-01 12:31:42.174360                                            -120.12
# 2017-01-01 12:31:42.174370                                             -32.23
# 2017-01-01 12:31:42.174380                                            -335.94
# 2017-01-01 12:31:42.174390                                            -270.51
#
#                             <function <listcomp>.<lambda> at 0x00000139E279DE40>  \
# Time
# 2017-01-01 12:31:39.000000                                            -245.61
# 2017-01-01 12:31:39.000020                                            -259.77
# 2017-01-01 12:31:39.000040                                            -255.86
# 2017-01-01 12:31:39.000050                                            -237.79
# 2017-01-01 12:31:39.000060                                            -262.70
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            1999.94
# 2017-01-01 12:31:42.174360                                            1999.94
# 2017-01-01 12:31:42.174370                                            1999.94
# 2017-01-01 12:31:42.174380                                            1999.94
# 2017-01-01 12:31:42.174390                                            1999.94
#
#                             <function <listcomp>.<lambda> at 0x00000139E279EE80>  \
# Time
# 2017-01-01 12:31:39.000000                                               2.83
# 2017-01-01 12:31:39.000020                                               2.11
# 2017-01-01 12:31:39.000040                                               0.38
# 2017-01-01 12:31:39.000050                                               2.92
# 2017-01-01 12:31:39.000060                                               1.57
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            -102.01
# 2017-01-01 12:31:42.174360                                             -76.78
# 2017-01-01 12:31:42.174370                                             -89.89
# 2017-01-01 12:31:42.174380                                            -118.83
# 2017-01-01 12:31:42.174390                                            -104.93
#
#                             <function <listcomp>.<lambda> at 0x00000139E279EF20>  \
# Time
# 2017-01-01 12:31:39.000000                                               0.06
# 2017-01-01 12:31:39.000020                                               0.11
# 2017-01-01 12:31:39.000040                                              -1.37
# 2017-01-01 12:31:39.000050                                              -1.66
# 2017-01-01 12:31:39.000060                                              -5.16
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            -167.58
# 2017-01-01 12:31:42.174360                                              66.12
# 2017-01-01 12:31:42.174370                                             -54.86
# 2017-01-01 12:31:42.174380                                             -64.73
# 2017-01-01 12:31:42.174390                                             -95.09
#
#                             <function <listcomp>.<lambda> at 0x00000139E279D760>  \
# Time
# 2017-01-01 12:31:39.000000                                               1.63
# 2017-01-01 12:31:39.000020                                               3.50
# 2017-01-01 12:31:39.000040                                               1.88
# 2017-01-01 12:31:39.000050                                               2.78
# 2017-01-01 12:31:39.000060                                               2.76
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                             -47.12
# 2017-01-01 12:31:42.174360                                            -104.92
# 2017-01-01 12:31:42.174370                                               8.56
# 2017-01-01 12:31:42.174380                                              43.26
# 2017-01-01 12:31:42.174390                                               2.82
#
#                             <function <listcomp>.<lambda> at 0x00000139E279DB20>  \
# Time
# 2017-01-01 12:31:39.000000                                            -611.70
# 2017-01-01 12:31:39.000020                                            -610.50
# 2017-01-01 12:31:39.000040                                            -612.60
# 2017-01-01 12:31:39.000050                                            -611.85
# 2017-01-01 12:31:39.000060                                            -611.25
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                             327.60
# 2017-01-01 12:31:42.174360                                             354.00
# 2017-01-01 12:31:42.174370                                             346.50
# 2017-01-01 12:31:42.174380                                             358.35
# 2017-01-01 12:31:42.174390                                             364.50
#
#                             <function <listcomp>.<lambda> at 0x00000139E279F4C0>  \
# Time
# 2017-01-01 12:31:39.000000                                            -337.65
# 2017-01-01 12:31:39.000020                                            -337.95
# 2017-01-01 12:31:39.000040                                            -340.65
# 2017-01-01 12:31:39.000050                                            -339.45
# 2017-01-01 12:31:39.000060                                            -339.15
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            -487.05
# 2017-01-01 12:31:42.174360                                            -473.70
# 2017-01-01 12:31:42.174370                                            -456.15
# 2017-01-01 12:31:42.174380                                            -444.15
# 2017-01-01 12:31:42.174390                                            -423.00
#
#                             <function <listcomp>.<lambda> at 0x00000139E279F560>  \
# Time
# 2017-01-01 12:31:39.000000                                            -116.70
# 2017-01-01 12:31:39.000020                                            -115.95
# 2017-01-01 12:31:39.000040                                            -112.05
# 2017-01-01 12:31:39.000050                                            -115.80
# 2017-01-01 12:31:39.000060                                            -116.40
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                            -918.15
# 2017-01-01 12:31:42.174360                                            -915.75
# 2017-01-01 12:31:42.174370                                            -904.95
# 2017-01-01 12:31:42.174380                                            -902.40
# 2017-01-01 12:31:42.174390                                            -911.85
#
#                             <function <listcomp>.<lambda> at 0x00000139E279EDE0>
# Time
# 2017-01-01 12:31:39.000000                                              35.60
# 2017-01-01 12:31:39.000020                                              35.79
# 2017-01-01 12:31:39.000040                                              35.89
# 2017-01-01 12:31:39.000050                                              35.75
# 2017-01-01 12:31:39.000060                                              35.79
# ...                                                                       ...
# 2017-01-01 12:31:42.174340                                              52.81
# 2017-01-01 12:31:42.174360                                              52.76
# 2017-01-01 12:31:42.174370                                              52.57
# 2017-01-01 12:31:42.174380                                              52.76
# 2017-01-01 12:31:42.174390                                              52.66
#
# [267274 rows x 10 columns]

# %%
import os 
relevant_path = "'E:/video'"
included_extensions = ['txt']
file_names = [fn for fn in os.listdir(relevant_path)
              if any(fn.endswith(ext) for ext in included_extensions)]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[31], line 4
#       2 relevant_path = "'E:/video'"
#       3 included_extensions = ['txt']
# ----> 4 file_names = [fn for fn in os.listdir(relevant_path)
#       5               if any(fn.endswith(ext) for ext in included_extensions)]
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: "'E:/video'"

# %%
for i in os.walk('E:/video'):
    print(i[0])
# Out:
# E:/video
# E:/video\.thumb
# E:/video\.snap

# %%
gps_folder_path = 'E:/video'
GPS_tracks = []
for i in os.listdir(gps_folder_path):
    if i.endswith('.txt'):
        GPS_tracks.append(i)

# %%
import pandas as pd
GPS = pd.DataFrame()
GPS['File'] = GPS_tracks
GPS['File'] = GPS['File'].apply(lambda x: f'{gps_folder_path}/{x}')
GPS['RAW Data'] = GPS['File'].apply(lambda x: pd.read_csv(x))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[40], line 5
#       3 GPS['File'] = GPS_tracks
#       4 GPS['File'] = GPS['File'].apply(lambda x: f'{gps_folder_path}/{x}')
# ----> 5 GPS['RAW Data'] = GPS['File'].apply(lambda x: pd.read_csv(x))
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[40], line 5, in <lambda>(x)
#       3 GPS['File'] = GPS_tracks
#       4 GPS['File'] = GPS['File'].apply(lambda x: f'{gps_folder_path}/{x}')
# ----> 5 GPS['RAW Data'] = GPS['File'].apply(lambda x: pd.read_csv(x))
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608     return parser
#     610 with parser:
# --> 611     return parser.read(nrows)
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1778, in TextFileReader.read(self, nrows)
#    1771 nrows = validate_integer("nrows", nrows)
#    1772 try:
#    1773     # error: "ParserBase" has no attribute "read"
#    1774     (
#    1775         index,
#    1776         columns,
#    1777         col_dict,
# -> 1778     ) = self._engine.read(  # type: ignore[attr-defined]
#    1779         nrows
#    1780     )
#    1781 except Exception:
#    1782     self.close()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     228 try:
#     229     if self.low_memory:
# --> 230         chunks = self._reader.read_low_memory(nrows)
#     231         # destructive to chunks
#     232         data = _concatenate_chunks(chunks)
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:808, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:866, in pandas._libs.parsers.TextReader._read_rows()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:852, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File c:\Users\mm21cu\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\parsers.pyx:1973, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 3, saw 13

# %%
x= GPS['File'][20]
x
# Out:
# 'E:/video/20230331_115346A.txt'

# %%
gps_track = []
file_data = open(x, 'r').read()
init_time = float(file_data.split('\n')[0].split('= ')[1])
increments = float(file_data.split('\n')[1].split('= ')[1])
for i in file_data.split('\n')[2:]:
    gps_track.append(i.split(','))
df = pd.DataFrame(gps_track)
df.columns=[0,'dt',2,'Alt','Latitude','Longitude','Speed','Course','Satellites','N Sat','g1','g2','g3']
df = df[:-1]
df ['dt'] = df ['dt'].apply(lambda x: int(x)*increments+init_time)
df['dt'] = df['dt'].apply(lambda x: datetime.fromtimestamp(float(x)))
df['Latitude'] = df['Latitude'].apply(lambda x: float(x)/10000000)
df['Longitude'] = df['Longitude'].apply(lambda x: float(x)/10000000)
df
# Out:
#       0                      dt  2       Alt   Latitude  Longitude Speed  \
# 0    10 2023-03-31 12:53:47.243  2  16534460  30.269119 -84.188766  0.00
# 1    10 2023-03-31 12:53:47.442  2  16534480  30.269119 -84.188766  0.07
# 2    10 2023-03-31 12:53:47.690  2  16534500  30.269119 -84.188766  0.03
# 3    10 2023-03-31 12:53:47.844  2  16534520  30.269119 -84.188766  0.01
# 4    10 2023-03-31 12:53:48.051  2  16534540  30.269119 -84.188766  0.00
# ..   ..                     ... ..       ...        ...        ...   ...
# 300  10 2023-03-31 12:54:47.233  2  16544460  30.269112 -84.188766  0.28
# 301  10 2023-03-31 12:54:47.432  2  16544480  30.269112 -84.188766  0.27
# 302  10 2023-03-31 12:54:47.633  2  16544500  30.269112 -84.188766  0.26
# 303  10 2023-03-31 12:54:47.835  2  16544520  30.269112 -84.188766  0.26
# 304  10 2023-03-31 12:54:48.034  2  16544540  30.269111 -84.188766  0.26
#
#      Course Satellites N Sat    g1   g2     g3
# 0     11.26       DAAN    17  0.67  615  -29.6
# 1     11.26       DAAN    16  0.72  615  -29.6
# 2     11.26       DAAN    17  0.67  615  -29.6
# 3     11.26       DAAN    17  0.67  615  -29.6
# 4     11.26       DAAN    15  0.77  615  -29.6
# ..      ...        ...   ...   ...  ...    ...
# 300  211.20       DAAN     6  1.22  582  -29.6
# 301  208.19       DAAN     6  1.22  582  -29.6
# 302  213.03       DAAN     6  1.22  582  -29.6
# 303  213.11       DAAN     6  1.22  582  -29.6
# 304  213.26       DAAN     6  1.22  582  -29.6
#
# [305 rows x 13 columns]

# %%
import folium
m = folium.Map(location=[df['Latitude'].mean(), df['Longitude'].mean()], zoom_start=15)
for i in range(len(df)):
    folium.Marker([df['Latitude'][i], df['Longitude'][i]], popup=f'{df["dt"][i]}').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63eadb788c98062eef5894a0430d63df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63eadb788c98062eef5894a0430d63df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63eadb788c98062eef5894a0430d63df = L.map(
#                 &quot;map_63eadb788c98062eef5894a0430d63df&quot;,
#                 {
#                     center: [30.26911846229508, -84.18876445245901],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_284cd273775320473a4303a29363c151 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_63eadb788c98062eef5894a0430d63df);
#
#
#             var marker_f9ed9ce1ab4b0b12af2986d864fc18ea = L.marker(
#                 [30.269119, -84.188766],
#                 {}
#             ).addTo(map_63eadb788c98062eef5894a0430d63df);
#
#
#         var popup_34bfa482fe0ba8ae7753d5fb7af896c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1862485d794608b95db81e16d9b73209 = $(`&lt;div id=&quot;html_1862485d794608b95db81e16d9b73209&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-03-31 12:53:47.243000&lt;/div&gt;`)[0];
#                 popup_34bfa482fe0ba8ae7753d5fb7af896c6.setContent(html_1862485d794608b95db81e16d9b73209);
#
#
#
#         marker_f9ed9ce1ab4b0b12af2986d864fc18ea.bindPopup(popup_34bfa482fe0ba8ae7753d5fb7af896c6)
#         ;
#
#
#
#
#             var marker_b30e875c00630562d34269d4029f8452 = L.marker(
#                 [30.269119, -84.188766],
#                 {}
#             ).addTo(map_63eadb788c98062eef5894a0430d63df);
#
#
#         var popup_5d08f39af470f5e75ef645f1aaa081e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c48e3db06179b42ecfc7ab73a2375ef6 = $(`&lt;div id=&quot;html_c48e3db06179b42ecfc7ab73a2375ef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-03-31 12:53:47.442000&lt;/div&gt;`)[0];
#                 popup_5d08f39af470f5e75ef645f1aaa081e9.setContent(html_c48e3db06179b42ecfc7ab73a2375ef6);
#
#
#
#         marker_b30e875c00630562d34269d4029f8452.bindPopup(popup_5d08f39af470f5e75ef645f1aaa081e9)
#         ;
#
#
#
#
#             var marker_49a65731fb4809dc65b25c332bca136c = L.marker(
#                 [30.269119, -84.188766],
#                 {}
#             ).addTo(map_63eadb788c98062eef5894a0430d63df);
#
#
#         var popup_d4ab56eb49b7db9320b860cf424f4ad8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f75d302c7c1423f10562381a11a3524a = $(`&lt;div id=&quot;html_f75d302c7c1423f10562381a11a3524a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-03-31 12:53:47.690000&lt;/div&gt;`)[0];
#                 popup_d4ab56eb49b7db9320b860cf424f4ad8.setContent(html_f75d302c7c1423f10562381a11a3524a);
#
#
#
#         marker_49a65731fb4809dc65b25c332bca136c.bindPopup(popup_d4ab56eb49b7db9320b860cf424f4ad8)
#         ;
#
#
#
#
#             var marker_f3b5a58599ed521247d16607d8eaed90 = L.marker(
#                 [30.269119, -84.188766],
#                 {}
#             ).addTo(map_63eadb788c98062eef5894a0430d63df);
#
#
#         var popup_a2af2e6f235f912548d4af39a7c369a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ce96c94dc4bf6914e8abee2898066836 = $(`&lt;div id=&quot;html_ce96c94dc4bf6914e8abee2898066836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-03-31 12:53:47.844000&lt;/div&gt;`)[0];
#                 popup_a2af2e6f235f912548d4af39a7c369a9.setContent(html_ce96c94dc4bf6914e8abee2898066836);
#
#
#
#         marker_f3b5a58599ed521247d16607d8eaed90.bindPopup(popup_a2af2e6f235f912548d4af39a7c369a9)
#         ;
#
#
#
#
#             var marker_b4cba491536ea8139d4578e4302994f0 = L.marker(
#                 [30.269119, -84.188766],
#                 {}
#             ).addTo(map_63eadb788c98062eef5894a0430d63df);
#
#
#         var popup_0d6a3b6efc9142de6523ffafa85f9ae3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9952ad0ed90b0e5a6ec26bd99604b095 = $(`&lt;div id=&quot;html_9952ad0ed90b0e5a6ec26bd99604b095&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2023-03-31 12:53:48.051000&lt;/div&gt;`)[0];
#                 popup_0d6a3b6efc9142de6523ffafa85f9ae3.setContent(html_9952ad0ed90b0e5a6ec26bd99604b095);
#
#
#
#         marker_b4cba491536ea8139d4578e4302994f0.bindPopup(popup_0d6a3b6efc9142de6523ffafa85f9ae3)
#         ;
#
#
#
#
#             var marker_e0ae6ecc999c54

# %%
df
# Out:
#       0      1  2                          Time   Latitude    Longitude  \
# 0    10     21  2 1970-01-01 00:00:00.016430360  302692760  -0841840550
# 1    10    221  2 1970-01-01 00:00:00.016430380  302692760  -0841840550
# 2    10    466  2 1970-01-01 00:00:00.016430400  302692760  -0841840550
# 3    10    620  2 1970-01-01 00:00:00.016430420  302692760  -0841840550
# 4    10    821  2 1970-01-01 00:00:00.016430440  302692760  -0841840550
# ..   ..    ... ..                           ...        ...          ...
# 300  10  60020  2 1970-01-01 00:00:00.016440360  302694710  -0841864090
# 301  10  60220  2 1970-01-01 00:00:00.016440380  302694710  -0841864260
# 302  10  60422  2 1970-01-01 00:00:00.016440400  302694710  -0841864420
# 303  10  60620  2 1970-01-01 00:00:00.016440420  302694710  -0841864590
# 304  10  60820  2 1970-01-01 00:00:00.016440440  302694710  -0841864750
#
#      Speed  Course Satellites N Sat    g1   g2     g3
# 0     0.01    1.76       AAAN    16  0.73  322  -29.6
# 1     0.01    1.76       AAAN    16  0.73  322  -29.6
# 2     0.04    1.76       AAAN    16  0.73  322  -29.6
# 3     0.05    1.76       AAAN    16  0.73  322  -29.6
# 4     0.04    1.76       AAAN    16  0.73  322  -29.6
# ..     ...     ...        ...   ...   ...  ...    ...
# 300  25.03  270.34       AAAN    16  0.74  375  -29.6
# 301  25.24  270.23       AAAN    16  0.74  375  -29.6
# 302  25.30  270.25       AAAN    16  0.74  376  -29.6
# 303  25.47  270.48       AAAN    16  0.74  377  -29.6
# 304  25.52  270.51       AAAN    16  0.74  378  -29.6
#
# [305 rows x 13 columns]
